# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import plotly.express as px
from prophet import Prophet

# %%
df = pd.read_csv('donnees_meteo_148_stations.csv')

# %% [markdown]
# #### Supression des station de ski fermées du dataset

# %%
stations_fermees = [
    "Alex", "Bozel", "Brison", "Burzier", "Cellier Valmorel", "Chamonix - les Pèlerins",
    "Col de Creusaz", "Col des Aravis", "Col du Champet", "Col du Chaussy", "Col du Frêne",
    "Col du Galibier", "Col du Plainpalais", "Col du Pré", "Col du Sommeiller", "Col du Tamié",
    "Crey Rond", "Doucy en Bauges", "Drouzin-Le-Mont", "Entremont", "Granier sur Aime",
    "Jarrier - La Tuvière", "La Sambuy", "Le Bouchet - Mont Charvin", "Le Cry - Salvagny",
    "Le Petit Bornand", "Les Bossons - Chamonix", "Marthod", "Molliessoulaz", "Montisel",
    "Notre Dame du pré", "Richebourg", "Saint Nicolas la Chapelle", "Saint-Jean de Sixt",
    "Sainte Foy", "Saxel", "Serraval", "Seytroux", "Sixt Fer à Cheval", "St-Pierre d'Entremont",
    "Termignon", "Thônes", "Thorens Glières", "Ugine", "Val Pelouse",
    "Verthemex - Mont du Chat", "Villards sur Thônes"
]

# %%
for station in stations_fermees:
    suppression = df[df["stations"].apply(lambda x: station in x)].index
    df = df.drop(suppression)

# %% [markdown]
# #### Suppression des colonnes inutiles du dataset

# %%
df = df.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y","temperature_2m_mean", "latitude", "longitude", "snowfall_water_equivalent_sum", "wind_speed_10m_mean", "sunshine_duration", "temperature_2m_max", "cloud_cover_mean","rain_sum",
       "temperature_2m_min"], axis=1)

# %% [markdown]
# #### Conversion des chutes de neige de centimètres en mètres

# %%
df.loc[:, "snowfall_sum"] = df["snowfall_sum"] / 100

# %% [markdown]
# ####

# %% [markdown]
# # PROPHET

# %%
# Conversion du type date
df['date'] = pd.to_datetime(df['date']).dt.tz_localize(None)

# Renom les colonnes pour Prophet
df = df.rename(columns={
    'date': 'ds',
    'snowfall_sum': 'y'
})

# %% [markdown]
# ## PROPHET par an

# %%
# Agrégation annuelle
df_annee = df.copy()
df_annee['ds'] = pd.to_datetime(df_annee['ds'])


# Supression des données après le 31/08/2024
df_annee = df_annee[df_annee["ds"] < "2025-01-01"]


df_annee = (
    df_annee
    .set_index('ds')
    .resample('YS')  # début de chaque année (ex: 2020-01-01)
    .agg({
        'y': 'sum',  # cumul de neige annuel    
        'altitude': 'first'
    })
    .dropna()
    .reset_index()
)

# %%
# Initialisation du modèle
model = Prophet(
    yearly_seasonality=False,  # utile car on a de la saisonnalité annuelle
    daily_seasonality=False,  # on n'a pas besoin de saisonnalité journalière ici
    weekly_seasonality=False,  # éventuellement activable si besoin
    changepoint_prior_scale=1,       # par défaut : 0.05
    seasonality_prior_scale=10          # par défaut : 10
)

# %%
# On s'assure de ne garder que les colonnes utiles et sans NaN
df_train = df_annee[['ds', 'y']]

# Entraînement
model.fit(df_train)

# Prévision
future = model.make_future_dataframe(periods=5, freq='YS')

forecast = model.predict(future)
# Out:
# 11:21:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:21 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.plot(forecast)
plt.title("Prévision des chutes de neige par an, pour toutes les stations en Savoie, Haute-Savoie et Isère")
plt.xlabel("Date")
plt.ylabel("Cumul de neige (mètres)")
plt.grid()
plt.show()

# %% [markdown]
# ## PROPHET par an par altitude

# %%
df_1000 = df[df["altitude"] < 1000.0]
df_1000_1300 = df[(df["altitude"] < 1300.0) & (df["altitude"] >= 1000.0)]
df_1300_1600 = df[(df["altitude"] < 1600.0) & (df["altitude"] >= 1300.0)]
df_1600 = df[df["altitude"] >= 1600.0]

# %% [markdown]
# #### En dessous de 1000 m d'altitude

# %%
# Agrégation annuelle
df_annee_1000 = df_1000.copy()
df_annee_1000['ds'] = pd.to_datetime(df_annee_1000['ds'])


# Supression des données après le 31/08/2024
df_annee_1000 = df_annee_1000[df_annee_1000["ds"] < "2025-01-01"]


df_annee_1000 = (
    df_annee_1000
    .set_index('ds')
    .resample('YS')  # début de chaque année (ex: 2020-01-01)
    .agg({
        'y': 'mean',  # cumul de neige annuel
        'altitude': 'first'
    })
    .dropna()
    .reset_index()
)

# %%
df_annee_1000['y'] = df_annee_1000['y'] * 365

# %%
# Initialisation du modèle
model = Prophet(
    yearly_seasonality=False,  # utile car on a de la saisonnalité annuelle
    daily_seasonality=False,  # on n'a pas besoin de saisonnalité journalière ici
    weekly_seasonality=False,  # éventuellement activable si besoin
    changepoint_prior_scale=1,       # par défaut : 0.05
    seasonality_prior_scale=10          # par défaut : 10
)

# %%
# On s'assure de ne garder que les colonnes utiles et sans NaN
df_train = df_annee_1000[['ds', 'y']]

# Entraînement
model.fit(df_train)

# Prévision
future = model.make_future_dataframe(periods=5, freq='YS')

forecast = model.predict(future)
# Out:
# 11:21:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:22 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.plot(forecast)
plt.ylim(1, 8)
plt.title("Prévision des chutes de neige par an, moyenne par station en dessous de 1000m d'altitude")
plt.xlabel("Date")
plt.ylabel("Cumul de neige (mètres)")
plt.grid()
plt.show()

# %% [markdown]
# #### Entre 1000 et 1300 m d'altitude

# %%
# Agrégation annuelle
df_annee_1000_1300 = df_1000_1300.copy()
df_annee_1000_1300['ds'] = pd.to_datetime(df_annee_1000_1300['ds'])


# Supression des données après le 31/08/2024
df_annee_1000_1300 = df_annee_1000_1300[df_annee_1000_1300["ds"] < "2025-01-01"]


df_annee_1000_1300 = (
    df_annee_1000_1300
    .set_index('ds')
    .resample('YS')  # début de chaque année (ex: 2020-01-01)
    .agg({
        'y': 'mean',  # cumul de neige annuel
        'altitude': 'first'
    })
    .dropna()
    .reset_index()
)

# %%
df_annee_1000_1300['y'] = df_annee_1000_1300['y'] * 365

# %%
# Initialisation du modèle
model = Prophet(
    yearly_seasonality=False,  # utile car on a de la saisonnalité annuelle
    daily_seasonality=False,  # on n'a pas besoin de saisonnalité journalière ici
    weekly_seasonality=False,  # éventuellement activable si besoin
    changepoint_prior_scale=1,       # par défaut : 0.05
    seasonality_prior_scale=10          # par défaut : 10
)

# %%
# On s'assure de ne garder que les colonnes utiles et sans NaN
df_train = df_annee_1000_1300[['ds', 'y']]

# Entraînement
model.fit(df_train)

# Prévision
future = model.make_future_dataframe(periods=5, freq='YS')

forecast = model.predict(future)
# Out:
# 11:21:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:22 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.plot(forecast)
plt.ylim(1, 8)
plt.title("Prévision des chutes de neige par an, moyenne par station entre 1000 et 1300 m d'altitude")
plt.xlabel("Date")
plt.ylabel("Cumul de neige (mètres)")
plt.grid()
plt.show()

# %% [markdown]
# #### Entre 1300 et 1600 m d'altitude

# %%
# Agrégation annuelle
df_annee_1300_1600 = df_1300_1600.copy()
df_annee_1300_1600['ds'] = pd.to_datetime(df_annee_1300_1600['ds'])


# Supression des données après le 31/08/2024
df_annee_1300_1600 = df_annee_1300_1600[df_annee_1300_1600["ds"] < "2025-01-01"]


df_annee_1300_1600 = (
    df_annee_1300_1600
    .set_index('ds')
    .resample('YS')  # début de chaque année (ex: 2020-01-01)
    .agg({
        'y': 'mean',  # cumul de neige annuel
        'altitude': 'first'
    })
    .dropna()
    .reset_index()
)

# %%
df_annee_1300_1600['y'] = df_annee_1300_1600['y'] * 365

# %%
# Initialisation du modèle
model = Prophet(
    yearly_seasonality=False,  # utile car on a de la saisonnalité annuelle
    daily_seasonality=False,  # on n'a pas besoin de saisonnalité journalière ici
    weekly_seasonality=False,  # éventuellement activable si besoin
    changepoint_prior_scale=1,       # par défaut : 0.05
    seasonality_prior_scale=10          # par défaut : 10
)

# %%
# On s'assure de ne garder que les colonnes utiles et sans NaN
df_train = df_annee_1300_1600[['ds', 'y']]

# Entraînement
model.fit(df_train)

# Prévision
future = model.make_future_dataframe(periods=5, freq='YS')

forecast = model.predict(future)
# Out:
# 11:21:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.plot(forecast)
plt.ylim(1, 8)
plt.title("Prévision des chutes de neige par an, moyenne par station entre 1300 et 1600 m d'altitude")
plt.xlabel("Date")
plt.ylabel("Cumul de neige (mètres)")
plt.grid()
plt.show()

# %% [markdown]
# #### Au dessus de 1600 m d'altitude

# %%
# Agrégation annuelle
df_annee_1600 = df_1600.copy()
df_annee_1600['ds'] = pd.to_datetime(df_annee_1600['ds'])


# Supression des données après le 31/08/2024
df_annee_1600 = df_annee_1600[df_annee_1600["ds"] < "2025-01-01"]


df_annee_1600 = (
    df_annee_1600
    .set_index('ds')
    .resample('YS')  # début de chaque année (ex: 2020-01-01)
    .agg({
        'y': 'mean',  # cumul de neige annuel
        'altitude': 'first'
    })
    .dropna()
    .reset_index()
)

# %%
df_annee_1600['y'] = df_annee_1600['y'] * 365

# %%
# Initialisation du modèle
model = Prophet(
    yearly_seasonality=False,  # utile car on a de la saisonnalité annuelle
    daily_seasonality=False,  # on n'a pas besoin de saisonnalité journalière ici
    weekly_seasonality=False,  # éventuellement activable si besoin
    changepoint_prior_scale=1,       # par défaut : 0.05
    seasonality_prior_scale=10          # par défaut : 10
)

# %%
# On s'assure de ne garder que les colonnes utiles et sans NaN
df_train = df_annee_1600[['ds', 'y']]

# Entraînement
model.fit(df_train)

# Prévision
future = model.make_future_dataframe(periods=5, freq='YS')

forecast = model.predict(future)
# Out:
# 11:21:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.plot(forecast)
plt.ylim(1, 8)
plt.title("Prévision des chutes de neige par an, moyenne par station au dessus de 1600 m d'altitude")
plt.xlabel("Date")
plt.ylabel("Cumul de neige (mètres)")
plt.grid()
plt.show()

# %% [markdown]
# ## PROPHET par station

# %%
df["stations"].unique()
# Out:
# array(['Les Arcs', 'Les Brasses', 'Tignes', 'Valmorel', 'Doucy',
#        'Les Saisies', 'Savoie Grand Revard', 'Les Bottières',
#        'Saint Colomban des Villards', 'Val Cenis', 'La Toussuire',
#        'Sollières - Sardières', 'Le Corbier', 'Les Karellis', 'Aussois',
#        "Saint Sorlin d'Arves", 'Passy Plaine Joux', 'Praz de Lys Sommand',
#        "Roc d'Enfer - St Jean d'Aulps", 'Saint Gervais Mont-Blanc',
#        'Aillons Margeriaz', 'Areches Beaufort', 'Crest Voland Cohennoz',
#        'Flumet - St Nicolas la Chapelle', 'La Rosière 1850',
#        'Montchavin - La Plagne', 'Peisey-Vallandry', 'Les Habères',
#        'Montmin - Col de la Forclaz', 'Méribel', 'Courchevel',
#        'Pralognan la Vanoise', 'Saint Martin de Belleville',
#        'Bonneval sur Arc', 'Les Menuires', 'Bessans', 'Val Thorens',
#        'Bramans', 'Champagny en Vanoise', 'Brides les Bains',
#        "Val d'Isère", 'La Plagne', 'La Tania', 'Morillon', 'Samoëns',
#        'Mont Saxonnex', 'Romme', 'Les Carroz', "La Chapelle d'Abondance",
#        'Bernex', 'Thollon les Memises', 'Le Semnoz', 'Gresse en Vercors',
#        'Lans en Vercors', "Le Collet d'Allevard", 'Les 2 Alpes',
#        'Les 7 Laux', 'Les Coulmes', 'Les Egaux', 'OZ 3300',
#        'Saint Hilaire du Touvet', "Alpe d'Huez", 'Alpe du Grand Serre',
#        'Auris en oisans', 'Autrans Méaudre', 'Chamrousse',
#        'Col de Marcieu', 'Corrençon en Vercors', 'Abondance', 'Chatel',
#        'Bellevaux - Hirmentaz', 'Montriond', 'Avoriaz', 'Morzine',
#        'Les Gets', 'Orelle', "Saint Jean d'Arves", 'La Norma',
#        'Albiez Montrond', 'Valmeinier', 'Valfréjus', 'Valloire',
#        'Le Reposoir', 'Flaine', 'Le Grand Bornand', 'Chamonix',
#        'Saint Pierre de Chartreuse / Le Planolet', 'Vaujany',
#        'Villard de Lans', 'Villard Reculas', 'Cordon', 'Megève',
#        'Praz sur Arly', 'Les Contamines Montjoie',
#        'Notre Dame de Bellecombe', 'La Clusaz', 'Combloux', 'Les Houches',
#        'La Giettaz', 'Manigod'], dtype=object)

# %%
station_choisie = input("Entrez le nom de la station pour laquelle vous souhaitez afficher des prédictions : ")

# %%
df_station = df[df['stations'] == station_choisie]

# %%
df_station_agg = (
    df_station
    .set_index('ds')
    .resample('YS')
    .agg({
        'y': 'sum',  # cumul de neige par an
        'altitude': 'first'
    })
    .dropna()
    .reset_index()
)

# %%
# Paramètres du modèle
model = Prophet(
    yearly_seasonality=False,
    weekly_seasonality=False,
    daily_seasonality=False,
    changepoint_prior_scale=1,       # par défaut : 0.05
    seasonality_prior_scale=10          # par défaut : 10
)

# Entraînement
model.fit(df_station_agg)
# Out:
# 11:21:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=5, freq='YS')

forecast = model.predict(future)

# %%
fig = model.plot(forecast)
plt.title(f"Prévision des chutes de neige par an – Station : {station_choisie}")
plt.xlabel("Année")
plt.ylabel("Cumul de neige (mètres)")
plt.grid()
plt.show()
